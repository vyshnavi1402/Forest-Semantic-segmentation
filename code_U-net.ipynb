# %% [markdown]
# #                                    Using U-Net

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os
import random
import cv2
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input, Dropout
from tensorflow.keras.models import Model

plt.rcParams['figure.figsize'] = (20,8)
plt.rcParams['font.size'] = 16

# %%
base_directory = '../input/augmented-forest-segmentation/Forest Segmented/Forest Segmented'
images_folder = os.path.join(base_directory, 'images')
masks_folder = os.path.join(base_directory, 'masks')
data = pd.read_csv(os.path.join(base_directory, 'meta_data.csv'))

# %%
data.head()
# Out:
#                image                mask
# 0   10452_sat_08.jpg   10452_mask_08.jpg
# 1   10452_sat_18.jpg   10452_mask_18.jpg
# 2  111335_sat_00.jpg  111335_mask_00.jpg
# 3  111335_sat_01.jpg  111335_mask_01.jpg
# 4  111335_sat_02.jpg  111335_mask_02.jpg

# %%
img_dim = 256

image_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.15)
mask_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.15)

train_image_generator = image_datagen.flow_from_directory(
        '../input/augmented-forest-segmentation/Forest Segmented/Forest Segmented',
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['images'],
        batch_size = 32,
        seed=42,
        subset='training')
    
train_mask_generator = mask_datagen.flow_from_directory(
        '../input/augmented-forest-segmentation/Forest Segmented/Forest Segmented',
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['masks'],
        color_mode = 'grayscale',
        batch_size = 32,
        seed=42,
        subset='training')

val_image_generator = image_datagen.flow_from_directory(
        '../input/augmented-forest-segmentation/Forest Segmented/Forest Segmented',
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['images'],
        batch_size = 32,
        seed=42,
        subset='validation')
    
val_mask_generator = mask_datagen.flow_from_directory(
        '../input/augmented-forest-segmentation/Forest Segmented/Forest Segmented',
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['masks'],
        color_mode = 'grayscale',
        batch_size = 32,
        seed=42,
        subset='validation')

train_generator = zip(train_image_generator, train_mask_generator)
val_generator = zip(val_image_generator, val_mask_generator)
# Out:
# Found 4342 images belonging to 1 classes.
# Found 4342 images belonging to 1 classes.
# Found 766 images belonging to 1 classes.
# Found 766 images belonging to 1 classes.

# %%
training_samples_size = train_image_generator.samples
val_samples_size = val_image_generator.samples

# %%
n = 0
for i,m in train_generator:
    img,mask = i,m

    if n < 5:
        fig, axs = plt.subplots(1 , 2, figsize=(20,4))
        axs[0].imshow(img[0])
        axs[0].set_title('Input Image')
        axs[1].imshow(mask[0],cmap='gray')
        axs[1].set_title('Mask Image')
        plt.show()
        n+=1
    else:
        break

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    b1 = conv_block(p4, 512)

    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
from keras import backend as K

def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

def iou_coef_loss(y_true, y_pred):
    return -iou_coef(y_true, y_pred)

def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = label(y_true_in > 0.5)
    y_pred = label(y_pred_in > 0.5)
    
    true_objects = len(np.unique(labels))
    pred_objects = len(np.unique(y_pred))

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.array(np.mean(metric), dtype=np.float32)

def my_iou_metric(label, pred):
    metric_value = tf.compat.v1.py_func(iou_metric_batch, [label, pred], tf.float32)
    return metric_value

# %%
input_shape = (img_dim, img_dim, 3)
model = build_unet(input_shape)
model.compile(optimizer = tf.keras.optimizers.Adam(lr = 0.001), loss = ['binary_crossentropy'], metrics=[iou_coef,'accuracy'])
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 256, 256, 32) 896         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 256, 256, 32) 128         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 256, 256, 32) 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 256, 256, 32) 9248        activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 256, 256, 32) 128         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 256, 256, 32) 0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 128, 128, 32) 0           activation_73[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 128, 128, 64) 18496       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 128, 128, 64) 256         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 128, 128, 64) 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 128, 128, 64) 36928       activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 128, 128, 64) 256         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 128, 128, 64) 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 64, 64, 64)   0           activation_75[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 64, 64, 128)  73856       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 64, 64, 128)  512         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 64, 64, 128)  0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 64, 64, 128)  147584      activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 64, 64, 128)  512         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 64, 64, 128)  0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 32, 32, 128)  0           activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 32, 32, 256)  295168      max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 32, 32, 256)  1024        conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 32, 32, 256)  0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 32, 32, 256)  590080      activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 32, 32, 256)  1024        conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 32, 32, 256)  0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 16, 16, 256)  0           activation_79[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 16, 16, 512)  1180160     max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 16, 16, 512)  2048        conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 16, 16, 512)  0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 16, 16, 512)  2359808     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 16, 16, 512)  2048        conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 16, 16, 512)  0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 32, 32, 256)  524544      activation_81[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 32, 32, 512)  0           conv2d_transpose_16[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 32, 32, 256)  1024        conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 32, 32, 256)  0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 32, 32, 256)  590080      activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 32, 32, 256)  1024        conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 32, 32, 256)  0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 64, 64, 128)  131200      activation_83[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 64, 64, 256)  0           conv2d_transpose_17[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 64, 64, 128)  512         conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 64, 64, 128)  0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 64, 64, 128)  147584      activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 64, 64, 128)  512         conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 64, 64, 128)  0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 128, 128, 64) 32832       activation_85[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 128, 128, 128 0           conv2d_transpose_18[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 128, 128, 64) 256         conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 128, 128, 64) 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 128, 128, 64) 36928       activation_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 128, 128, 64) 256         conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 128, 128, 64) 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 256, 256, 32) 8224        activation_87[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 256, 256, 64) 0           conv2d_transpose_19[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 256, 256, 32) 128         conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 256, 256, 32) 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 256, 256, 32) 9248        activation_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 256, 256, 32) 128         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 256, 256, 32) 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 256, 256, 1)  33          activation_89[0][0]
# ==================================================================================================
# Total params: 7,771,873
# Trainable params: 7,765,985
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
model_path = "unet.h5"
checkpoint = ModelCheckpoint(model_path,
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)

# %%
history = model.fit(train_generator,
                    steps_per_epoch=training_samples_size//32,
                    validation_data=val_generator,
                    validation_steps=val_samples_size//32,
                    epochs=50, callbacks=[earlystop, checkpoint])
# Out:
# Epoch 1/50
# 135/135 [==============================] - 53s 374ms/step - loss: 0.5329 - iou_coef: 0.4984 - accuracy: 0.7434 - val_loss: 12.9610 - val_iou_coef: 0.0029 - val_accuracy: 0.3681
#
# Epoch 00001: val_loss improved from inf to 12.96098, saving model to unet.h5
# Epoch 2/50
# 135/135 [==============================] - 50s 374ms/step - loss: 0.4499 - iou_coef: 0.5443 - accuracy: 0.7943 - val_loss: 6.3986 - val_iou_coef: 0.0046 - val_accuracy: 0.3710
#
# Epoch 00002: val_loss improved from 12.96098 to 6.39858, saving model to unet.h5
# Epoch 3/50
# 135/135 [==============================] - 49s 366ms/step - loss: 0.4480 - iou_coef: 0.5511 - accuracy: 0.7940 - val_loss: 1.4272 - val_iou_coef: 0.2147 - val_accuracy: 0.5025
#
# Epoch 00003: val_loss improved from 6.39858 to 1.42720, saving model to unet.h5
# Epoch 4/50
# 135/135 [==============================] - 50s 372ms/step - loss: 0.4277 - iou_coef: 0.5627 - accuracy: 0.8018 - val_loss: 0.5457 - val_iou_coef: 0.5519 - val_accuracy: 0.7839
#
# Epoch 00004: val_loss improved from 1.42720 to 0.54573, saving model to unet.h5
# Epoch 5/50
# 135/135 [==============================] - 49s 363ms/step - loss: 0.4238 - iou_coef: 0.5648 - accuracy: 0.8029 - val_loss: 0.6141 - val_iou_coef: 0.5266 - val_accuracy: 0.7700
#
# Epoch 00005: val_loss did not improve from 0.54573
# Epoch 6/50
# 135/135 [==============================] - 50s 368ms/step - loss: 0.4247 - iou_coef: 0.5608 - accuracy: 0.8011 - val_loss: 0.5197 - val_iou_coef: 0.5187 - val_accuracy: 0.7958
#
# Epoch 00006: val_loss improved from 0.54573 to 0.51970, saving model to unet.h5
# Epoch 7/50
# 135/135 [==============================] - 49s 365ms/step - loss: 0.4223 - iou_coef: 0.5675 - accuracy: 0.8055 - val_loss: 1.4102 - val_iou_coef: 0.3778 - val_accuracy: 0.6473
#
# Epoch 00007: val_loss did not improve from 0.51970
# Epoch 8/50
# 135/135 [==============================] - 50s 368ms/step - loss: 0.4117 - iou_coef: 0.5689 - accuracy: 0.8081 - val_loss: 0.5874 - val_iou_coef: 0.4307 - val_accuracy: 0.7220
#
# Epoch 00008: val_loss did not improve from 0.51970
# Epoch 9/50
# 135/135 [==============================] - 49s 364ms/step - loss: 0.4062 - iou_coef: 0.5761 - accuracy: 0.8129 - val_loss: 0.8818 - val_iou_coef: 0.3788 - val_accuracy: 0.6187
#
# Epoch 00009: val_loss did not improve from 0.51970
# Epoch 10/50
# 135/135 [==============================] - 50s 369ms/step - loss: 0.4113 - iou_coef: 0.5668 - accuracy: 0.8075 - val_loss: 0.4555 - val_iou_coef: 0.6063 - val_accuracy: 0.8090
#
# Epoch 00010: val_loss improved from 0.51970 to 0.45546, saving model to unet.h5
# Epoch 11/50
# 135/135 [==============================] - 49s 364ms/step - loss: 0.3986 - iou_coef: 0.5818 - accuracy: 0.8133 - val_loss: 0.4405 - val_iou_coef: 0.5515 - val_accuracy: 0.8055
#
# Epoch 00011: val_loss improved from 0.45546 to 0.44051, saving model to unet.h5
# Epoch 12/50
# 135/135 [==============================] - 50s 368ms/step - loss: 0.4019 - iou_coef: 0.5761 - accuracy: 0.8122 - val_loss: 0.4826 - val_iou_coef: 0.5607 - val_accuracy: 0.7710
#
# Epoch 00012: val_loss did not improve from 0.44051
# Epoch 13/50
# 135/135 [==============================] - 49s 365ms/step - loss: 0.3983 - iou_coef: 0.5716 - accuracy: 0.8165 - val_loss: 0.4695 - val_iou_coef: 0.5009 - val_accuracy: 0.7665
#
# Epoch 00013: val_loss did not improve from 0.44051
# Epoch 14/50
# 135/135 [==============================] - 49s 366ms/step - loss: 0.3931 - iou_coef: 0.5799 - accuracy: 0.8189 - val_loss: 0.4069 - val_iou_coef: 0.5817 - val_accuracy: 0.8170
#
# Epoch 00014: val_loss improved from 0.44051 to 0.40692, saving model to unet.h5
# Epoch 15/50
# 135/135 [==============================] - 49s 366ms/step - loss: 0.3845 - iou_coef: 0.5912 - accuracy: 0.8230 - val_loss: 0.4702 - val_iou_coef: 0.5868 - val_accuracy: 0.7975
#
# Epoch 00015: val_loss did not improve from 0.40692
# Epoch 16/50
# 135/135 [==============================] - 49s 365ms/step - loss: 0.3858 - iou_coef: 0.5844 - accuracy: 0.8238 - val_loss: 0.4575 - val_iou_coef: 0.5946 - val_accuracy: 0.8097
#
# Epoch 00016: val_loss did not improve from 0.40692
# Epoch 17/50
# 135/135 [==============================] - 50s 367ms/step - loss: 0.3890 - iou_coef: 0.5834 - accuracy: 0.8190 - val_loss: 0.4010 - val_iou_coef: 0.6144 - val_accuracy: 0.8253
#
# Epoch 00017: val_loss improved from 0.40692 to 0.40100, saving model to unet.h5
# Epoch 18/50
# 135/135 [==============================] - 49s 362ms/step - loss: 0.3860 - iou_coef: 0.5844 - accuracy: 0.8211 - val_loss: 0.7341 - val_iou_coef: 0.4121 - val_accuracy: 0.6792
#
# Epoch 00018: val_loss did not improve from 0.40100
# Epoch 19/50
# 135/135 [==============================] - 50s 369ms/step - loss: 0.3802 - iou_coef: 0.5872 - accuracy: 0.8242 - val_loss: 0.4536 - val_iou_coef: 0.5986 - val_accuracy: 0.8041
#
# Epoch 00019: val_loss did not improve from 0.40100
# Epoch 20/50
# 135/135 [==============================] - 49s 364ms/step - loss: 0.3863 - iou_coef: 0.5901 - accuracy: 0.8191 - val_loss: 0.3938 - val_iou_coef: 0.6170 - val_accuracy: 0.8253
#
# Epoch 00020: val_loss improved from 0.40100 to 0.39384, saving model to unet.h5
# Epoch 21/50
# 135/135 [==============================] - 49s 364ms/step - loss: 0.3760 - iou_coef: 0.5904 - accuracy: 0.8264 - val_loss: 0.4834 - val_iou_coef: 0.5871 - val_accuracy: 0.7984
#
# Epoch 00021: val_loss did not improve from 0.39384
# Epoch 22/50
# 135/135 [==============================] - 49s 364ms/step - loss: 0.3679 - iou_coef: 0.6027 - accuracy: 0.8307 - val_loss: 0.5188 - val_iou_coef: 0.5610 - val_accuracy: 0.7769
#
# Epoch 00022: val_loss did not improve from 0.39384
# Epoch 23/50
# 135/135 [==============================] - 49s 364ms/step - loss: 0.3744 - iou_coef: 0.5935 - accuracy: 0.8260 - val_loss: 0.4614 - val_iou_coef: 0.5034 - val_accuracy: 0.7788
#
# Epoch 00023: val_loss did not improve from 0.39384
# Epoch 24/50
# 135/135 [==============================] - 49s 361ms/step - loss: 0.3688 - iou_coef: 0.5932 - accuracy: 0.8321 - val_loss: 0.3945 - val_iou_coef: 0.6151 - val_accuracy: 0.8253
#
# Epoch 00024: val_loss did not improve from 0.39384
# Epoch 25/50
# 135/135 [==============================] - 49s 361ms/step - loss: 0.3561 - iou_coef: 0.6037 - accuracy: 0.8340 - val_loss: 0.4196 - val_iou_coef: 0.5671 - val_accuracy: 0.8069
# Restoring model weights from the end of the best epoch.
#
# Epoch 00025: val_loss did not improve from 0.39384
# Epoch 00025: early stopping

# %%
import seaborn as sns
sns.set_style('dark')

# %% [markdown]
# ## Learning Curve

# %%
plt.figure(figsize=(20,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.ylim([0,2])
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
random_val_samples = val_generator.__next__()
val_image_samples = random_val_samples[0]
val_mask_samples = random_val_samples[1]
predicted_masks = model.predict(val_image_samples)

predicted_masks[predicted_masks >= 0.5] = 1
predicted_masks[predicted_masks < 0.5] = 0

# %% [markdown]
# ## Ground Truth Masks vs Predicted Masks

# %%
f, axarr = plt.subplots(15,3,figsize=(20, 60))

for i in range(0,15):

    axarr[i,0].imshow(val_image_samples[i])
    axarr[i,0].title.set_text('Original Image')
    axarr[i,0].axis('off')
    axarr[i,1].imshow(val_mask_samples[i])
    axarr[i,1].title.set_text('Actual Mask')
    axarr[i,1].axis('off')
    axarr[i,2].imshow(predicted_masks[i])
    axarr[i,2].title.set_text('Predicted Mask')
    axarr[i,2].axis('off')
